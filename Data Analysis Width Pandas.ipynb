# %% [markdown]
# #Classifications

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv("client_list.csv")

# %%
df2=pd.read_table("client_list.table")

# %%
df3=.read_txt("client_list.txt")
# Out:
#   Input In [127]
#     df3=.read_txt("client_list.txt")
#         ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("client_list_practice.csv")
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0    Jennifer     Jones      F  27.0      black     brown
# 1       Jaime   Roberts      M  32.0      brown     hazel
# 2     Michael   Johnson      M  55.0        red     green
# 3        Mary       NaN      F  42.0     blonde       NaN
# 4         NaN  Phillips      M  37.0        NaN     brown
# 5      Thomas     Moore      M  60.0      brown      blue
# 6     Natalie    Potter      F   NaN      brown     green
# 7      Brenda     Jones      F   NaN        NaN     brown
# 8     Michael     Smith    NaN  58.0      brown     brown
# 9    Jennifer     Smith      F  36.0      black     brown
# 10    Michael     Smith      M  37.0      black     hazel
# 11    Jessica       NaN      F  19.0      black      blue
# 12      Molly    Bryant      F  21.0      brown      blue
# 13      Jaime  Anderson      F  46.0      brown     green

# %%
pd.read_csv("client_list_practice.csv").drop(["FIRST_NAME","AGE","EYE_COLOR"], axis=1)#axis=0 dersek satırsiler , 1 dersek sütun siler
# Out:
#    LAST_NAME GENDER HAIR_COLOR
# 0      Jones      F      black
# 1    Roberts      M      brown
# 2    Johnson      M        red
# 3        NaN      F     blonde
# 4   Phillips      M        NaN
# 5      Moore      M      brown
# 6     Potter      F      brown
# 7      Jones      F        NaN
# 8      Smith    NaN      brown
# 9      Smith      F      black
# 10     Smith      M      black
# 11       NaN      F      black
# 12    Bryant      F      brown
# 13  Anderson      F      brown

# %%
#EDA - EXPLORATORY DATA ANALYSİS

# %%
df1=pd.read_csv("client_list_practice.csv")

# %%
df1.head(3)
# Out:
#   FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0   Jennifer     Jones      F  27.0      black     brown
# 1      Jaime   Roberts      M  32.0      brown     hazel
# 2    Michael   Johnson      M  55.0        red     green

# %%
df=df1

# %%
df
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0    Jennifer     Jones      F  27.0      black     brown
# 1       Jaime   Roberts      M  32.0      brown     hazel
# 2     Michael   Johnson      M  55.0        red     green
# 3        Mary       NaN      F  42.0     blonde       NaN
# 4         NaN  Phillips      M  37.0        NaN     brown
# 5      Thomas     Moore      M  60.0      brown      blue
# 6     Natalie    Potter      F   NaN      brown     green
# 7      Brenda     Jones      F   NaN        NaN     brown
# 8     Michael     Smith    NaN  58.0      brown     brown
# 9    Jennifer     Smith      F  36.0      black     brown
# 10    Michael     Smith      M  37.0      black     hazel
# 11    Jessica       NaN      F  19.0      black      blue
# 12      Molly    Bryant      F  21.0      brown      blue
# 13      Jaime  Anderson      F  46.0      brown     green

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FIRST_NAME  13 non-null     object
#  1   LAST_NAME   12 non-null     object
#  2   GENDER      13 non-null     object
#  3   AGE         12 non-null     float64
#  4   HAIR_COLOR  12 non-null     object
#  5   EYE_COLOR   13 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 800.0+ bytes

# %%
df.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'GENDER', 'AGE', 'HAIR_COLOR', 'EYE_COLOR'], dtype='object')

# %%
ax=sns.countplot(x=df1["LAST_NAME"])
ax.bar_label(ax.containers[0]);

# %%
ax=sns.countplot(x=df["AGE"])
ax.bar_label(ax.containers[0]);

# %%
#Feature Enginnering

# %%
df["LAST_NAME"]
# Out:
# 0        Jones
# 1      Roberts
# 2      Johnson
# 3          NaN
# 4     Phillips
# 5        Moore
# 6       Potter
# 7        Jones
# 8        Smith
# 9        Smith
# 10       Smith
# 11         NaN
# 12      Bryant
# 13    Anderson
# Name: LAST_NAME, dtype: object

# %%
df.isnull().sum()
# Out:
# FIRST_NAME    1
# LAST_NAME     2
# GENDER        1
# AGE           2
# HAIR_COLOR    2
# EYE_COLOR     1
# dtype: int64

# %%
df.notnull().sum()
# Out:
# FIRST_NAME    13
# LAST_NAME     12
# GENDER        13
# AGE           12
# HAIR_COLOR    12
# EYE_COLOR     13
# dtype: int64

# %%
df.head(11)
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0    Jennifer     Jones      F  27.0      black     brown
# 1       Jaime   Roberts      M  32.0      brown     hazel
# 2     Michael   Johnson      M  55.0        red     green
# 3        Mary       NaN      F  42.0     blonde       NaN
# 4         NaN  Phillips      M  37.0        NaN     brown
# 5      Thomas     Moore      M  60.0      brown      blue
# 6     Natalie    Potter      F   NaN      brown     green
# 7      Brenda     Jones      F   NaN        NaN     brown
# 8     Michael     Smith    NaN  58.0      brown     brown
# 9    Jennifer     Smith      F  36.0      black     brown
# 10    Michael     Smith      M  37.0      black     hazel

# %%
df.head(5)
# Out:
#   FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0   Jennifer     Jones      F  27.0      black     brown
# 1      Jaime   Roberts      M  32.0      brown     hazel
# 2    Michael   Johnson      M  55.0        red     green
# 3       Mary       NaN      F  42.0     blonde       NaN
# 4        NaN  Phillips      M  37.0        NaN     brown

# %%
df.drop(["FIRST_NAME","GENDER","EYE_COLOR"], axis=1)
# Out:
#    LAST_NAME   AGE HAIR_COLOR
# 0      Jones  27.0      black
# 1    Roberts  32.0      brown
# 2    Johnson  55.0        red
# 3        NaN  42.0     blonde
# 4   Phillips  37.0        NaN
# 5      Moore  60.0      brown
# 6     Potter   NaN      brown
# 7      Jones   NaN        NaN
# 8      Smith  58.0      brown
# 9      Smith  36.0      black
# 10     Smith  37.0      black
# 11       NaN  19.0      black
# 12    Bryant  21.0      brown
# 13  Anderson  46.0      brown

# %%
df["LAST_NAME"].value_counts()
# Out:
# Smith       3
# Jones       2
# Roberts     1
# Johnson     1
# Phillips    1
# Moore       1
# Potter      1
# Bryant      1
# Anderson    1
# Name: LAST_NAME, dtype: int64

# %%
df[(df["LAST_NAME"]=="Smith")]
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 8     Michael     Smith    NaN  58.0      brown     brown
# 9    Jennifer     Smith      F  36.0      black     brown
# 10    Michael     Smith      M  37.0      black     hazel

# %%
df["HAIR_COLOR"].value_counts()
# Out:
# brown     6
# black     4
# red       1
# blonde    1
# Name: HAIR_COLOR, dtype: int64

# %%
df[(df["HAIR_COLOR"]!="black")]
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 1       Jaime   Roberts      M  32.0      brown     hazel
# 2     Michael   Johnson      M  55.0        red     green
# 3        Mary       NaN      F  42.0     blonde       NaN
# 4         NaN  Phillips      M  37.0        NaN     brown
# 5      Thomas     Moore      M  60.0      brown      blue
# 6     Natalie    Potter      F   NaN      brown     green
# 7      Brenda     Jones      F   NaN        NaN     brown
# 8     Michael     Smith    NaN  58.0      brown     brown
# 12      Molly    Bryant      F  21.0      brown      blue
# 13      Jaime  Anderson      F  46.0      brown     green

# %%
df[(df["HAIR_COLOR"]=="red")]
# Out:
#   FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 2    Michael   Johnson      M  55.0        red     green
